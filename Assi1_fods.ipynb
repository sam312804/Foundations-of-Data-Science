# %%
import pandas as pd
#reading the csv file
df=pd.read_csv("iris.csv")

# %%
df=pd.read_csv("iris.csv")
df
# Out:
#      x0   x1   x2   x3   x4            type
# 0     1  5.1  3.5  1.4  0.2     Iris-setosa
# 1     1  4.9  3.0  1.4  0.2     Iris-setosa
# 2     1  4.7  3.2  1.3  0.2     Iris-setosa
# 3     1  4.6  3.1  1.5  0.2     Iris-setosa
# 4     1  5.0  3.6  1.4  0.2     Iris-setosa
# ..   ..  ...  ...  ...  ...             ...
# 145   1  6.7  3.0  5.2  2.3  Iris-virginica
# 146   1  6.3  2.5  5.0  1.9  Iris-virginica
# 147   1  6.5  3.0  5.2  2.0  Iris-virginica
# 148   1  6.2  3.4  5.4  2.3  Iris-virginica
# 149   1  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df.iloc[ : ,1:5]
# Out:
#       x1   x2   x3   x4
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x0      150 non-null    int64
#  1   x1      150 non-null    float64
#  2   x2      150 non-null    float64
#  3   x3      150 non-null    float64
#  4   x4      150 non-null    float64
#  5   type    150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.sort_values(by="x1")
# Out:
#      x0   x1   x2   x3   x4            type
# 13    1  4.3  3.0  1.1  0.1     Iris-setosa
# 42    1  4.4  3.2  1.3  0.2     Iris-setosa
# 38    1  4.4  3.0  1.3  0.2     Iris-setosa
# 8     1  4.4  2.9  1.4  0.2     Iris-setosa
# 41    1  4.5  2.3  1.3  0.3     Iris-setosa
# ..   ..  ...  ...  ...  ...             ...
# 122   1  7.7  2.8  6.7  2.0  Iris-virginica
# 118   1  7.7  2.6  6.9  2.3  Iris-virginica
# 117   1  7.7  3.8  6.7  2.2  Iris-virginica
# 135   1  7.7  3.0  6.1  2.3  Iris-virginica
# 131   1  7.9  3.8  6.4  2.0  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df.describe()
# Out:
#           x0          x1          x2          x3          x4
# count  150.0  150.000000  150.000000  150.000000  150.000000
# mean     1.0    5.843333    3.054000    3.758667    1.198667
# std      0.0    0.828066    0.433594    1.764420    0.763161
# min      1.0    4.300000    2.000000    1.000000    0.100000
# 25%      1.0    5.100000    2.800000    1.600000    0.300000
# 50%      1.0    5.800000    3.000000    4.350000    1.300000
# 75%      1.0    6.400000    3.300000    5.100000    1.800000
# max      1.0    7.900000    4.400000    6.900000    2.500000

# %%
df.iloc[[10,12,17]]
# Out:
#     x0   x1   x2   x3   x4         type
# 10   1  5.4  3.7  1.5  0.2  Iris-setosa
# 12   1  4.8  3.0  1.4  0.1  Iris-setosa
# 17   1  5.1  3.5  1.4  0.3  Iris-setosa

# %%
#reading .txt file
df_txt = pd.read_csv("iris.csv")
df_txt
# Out:
#      x0   x1   x2   x3   x4            type
# 0     1  5.1  3.5  1.4  0.2     Iris-setosa
# 1     1  4.9  3.0  1.4  0.2     Iris-setosa
# 2     1  4.7  3.2  1.3  0.2     Iris-setosa
# 3     1  4.6  3.1  1.5  0.2     Iris-setosa
# 4     1  5.0  3.6  1.4  0.2     Iris-setosa
# ..   ..  ...  ...  ...  ...             ...
# 145   1  6.7  3.0  5.2  2.3  Iris-virginica
# 146   1  6.3  2.5  5.0  1.9  Iris-virginica
# 147   1  6.5  3.0  5.2  2.0  Iris-virginica
# 148   1  6.2  3.4  5.4  2.3  Iris-virginica
# 149   1  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
with open("iris.csv") as file:
   fileContent = file.read()
print(fileContent)
# Out:
# x0,x1,x2,x3,x4,type
# 1,5.1,3.5,1.4,0.2,Iris-setosa
# 1,4.9,3,1.4,0.2,Iris-setosa
# 1,4.7,3.2,1.3,0.2,Iris-setosa
# 1,4.6,3.1,1.5,0.2,Iris-setosa
# 1,5,3.6,1.4,0.2,Iris-setosa
# 1,5.4,3.9,1.7,0.4,Iris-setosa
# 1,4.6,3.4,1.4,0.3,Iris-setosa
# 1,5,3.4,1.5,0.2,Iris-setosa
# 1,4.4,2.9,1.4,0.2,Iris-setosa
# 1,4.9,3.1,1.5,0.1,Iris-setosa
# 1,5.4,3.7,1.5,0.2,Iris-setosa
# 1,4.8,3.4,1.6,0.2,Iris-setosa
# 1,4.8,3,1.4,0.1,Iris-setosa
# 1,4.3,3,1.1,0.1,Iris-setosa
# 1,5.8,4,1.2,0.2,Iris-setosa
# 1,5.7,4.4,1.5,0.4,Iris-setosa
# 1,5.4,3.9,1.3,0.4,Iris-setosa
# 1,5.1,3.5,1.4,0.3,Iris-setosa
# 1,5.7,3.8,1.7,0.3,Iris-setosa
# 1,5.1,3.8,1.5,0.3,Iris-setosa
# 1,5.4,3.4,1.7,0.2,Iris-setosa
# 1,5.1,3.7,1.5,0.4,Iris-setosa
# 1,4.6,3.6,1,0.2,Iris-setosa
# 1,5.1,3.3,1.7,0.5,Iris-setosa
# 1,4.8,3.4,1.9,0.2,Iris-setosa
# 1,5,3,1.6,0.2,Iris-setosa
# 1,5,3.4,1.6,0.4,Iris-setosa
# 1,5.2,3.5,1.5,0.2,Iris-setosa
# 1,5.2,3.4,1.4,0.2,Iris-setosa
# 1,4.7,3.2,1.6,0.2,Iris-setosa
# 1,4.8,3.1,1.6,0.2,Iris-setosa
# 1,5.4,3.4,1.5,0.4,Iris-setosa
# 1,5.2,4.1,1.5,0.1,Iris-setosa
# 1,5.5,4.2,1.4,0.2,Iris-setosa
# 1,4.9,3.1,1.5,0.1,Iris-setosa
# 1,5,3.2,1.2,0.2,Iris-setosa
# 1,5.5,3.5,1.3,0.2,Iris-setosa
# 1,4.9,3.1,1.5,0.1,Iris-setosa
# 1,4.4,3,1.3,0.2,Iris-setosa
# 1,5.1,3.4,1.5,0.2,Iris-setosa
# 1,5,3.5,1.3,0.3,Iris-setosa
# 1,4.5,2.3,1.3,0.3,Iris-setosa
# 1,4.4,3.2,1.3,0.2,Iris-setosa
# 1,5,3.5,1.6,0.6,Iris-setosa
# 1,5.1,3.8,1.9,0.4,Iris-setosa
# 1,4.8,3,1.4,0.3,Iris-setosa
# 1,5.1,3.8,1.6,0.2,Iris-setosa
# 1,4.6,3.2,1.4,0.2,Iris-setosa
# 1,5.3,3.7,1.5,0.2,Iris-setosa
# 1,5,3.3,1.4,0.2,Iris-setosa
# 1,7,3.2,4.7,1.4,Iris-versicolor
# 1,6.4,3.2,4.5,1.5,Iris-versicolor
# 1,6.9,3.1,4.9,1.5,Iris-versicolor
# 1,5.5,2.3,4,1.3,Iris-versicolor
# 1,6.5,2.8,4.6,1.5,Iris-versicolor
# 1,5.7,2.8,4.5,1.3,Iris-versicolor
# 1,6.3,3.3,4.7,1.6,Iris-versicolor
# 1,4.9,2.4,3.3,1,Iris-versicolor
# 1,6.6,2.9,4.6,1.3,Iris-versicolor
# 1,5.2,2.7,3.9,1.4,Iris-versicolor
# 1,5,2,3.5,1,Iris-versicolor
# 1,5.9,3,4.2,1.5,Iris-versicolor
# 1,6,2.2,4,1,Iris-versicolor
# 1,6.1,2.9,4.7,1.4,Iris-versicolor
# 1,5.6,2.9,3.6,1.3,Iris-versicolor
# 1,6.7,3.1,4.4,1.4,Iris-versicolor
# 1,5.6,3,4.5,1.5,Iris-versicolor
# 1,5.8,2.7,4.1,1,Iris-versicolor
# 1,6.2,2.2,4.5,1.5,Iris-versicolor
# 1,5.6,2.5,3.9,1.1,Iris-versicolor
# 1,5.9,3.2,4.8,1.8,Iris-versicolor
# 1,6.1,2.8,4,1.3,Iris-versicolor
# 1,6.3,2.5,4.9,1.5,Iris-versicolor
# 1,6.1,2.8,4.7,1.2,Iris-versicolor
# 1,6.4,2.9,4.3,1.3,Iris-versicolor
# 1,6.6,3,4.4,1.4,Iris-versicolor
# 1,6.8,2.8,4.8,1.4,Iris-versicolor
# 1,6.7,3,5,1.7,Iris-versicolor
# 1,6,2.9,4.5,1.5,Iris-versicolor
# 1,5.7,2.6,3.5,1,Iris-versicolor
# 1,5.5,2.4,3.8,1.1,Iris-versicolor
# 1,5.5,2.4,3.7,1,Iris-versicolor
# 1,5.8,2.7,3.9,1.2,Iris-versicolor
# 1,6,2.7,5.1,1.6,Iris-versicolor
# 1,5.4,3,4.5,1.5,Iris-versicolor
# 1,6,3.4,4.5,1.6,Iris-versicolor
# 1,6.7,3.1,4.7,1.5,Iris-versicolor
# 1,6.3,2.3,4.4,1.3,Iris-versicolor
# 1,5.6,3,4.1,1.3,Iris-versicolor
# 1,5.5,2.5,4,1.3,Iris-versicolor
# 1,5.5,2.6,4.4,1.2,Iris-versicolor
# 1,6.1,3,4.6,1.4,Iris-versicolor
# 1,5.8,2.6,4,1.2,Iris-versicolor
# 1,5,2.3,3.3,1,Iris-versicolor
# 1,5.6,2.7,4.2,1.3,Iris-versicolor
# 1,5.7,3,4.2,1.2,Iris-versicolor
# 1,5.7,2.9,4.2,1.3,Iris-versicolor
# 1,6.2,2.9,4.3,1.3,Iris-versicolor
# 1,5.1,2.5,3,1.1,Iris-versicolor
# 1,5.7,2.8,4.1,1.3,Iris-versicolor
# 1,6.3,3.3,6,2.5,Iris-virginica
# 1,5.8,2.7,5.1,1.9,Iris-virginica
# 1,7.1,3,5.9,2.1,Iris-virginica
# 1,6.3,2.9,5.6,1.8,Iris-virginica
# 1,6.5,3,5.8,2.2,Iris-virginica
# 1,7.6,3,6.6,2.1,Iris-virginica
# 1,4.9,2.5,4.5,1.7,Iris-virginica
# 1,7.3,2.9,6.3,1.8,Iris-virginica
# 1,6.7,2.5,5.8,1.8,Iris-virginica
# 1,7.2,3.6,6.1,2.5,Iris-virginica
# 1,6.5,3.2,5.1,2,Iris-virginica
# 1,6.4,2.7,5.3,1.9,Iris-virginica
# 1,6.8,3,5.5,2.1,Iris-virginica
# 1,5.7,2.5,5,2,Iris-virginica
# 1,5.8,2.8,5.1,2.4,Iris-virginica
# 1,6.4,3.2,5.3,2.3,Iris-virginica
# 1,6.5,3,5.5,1.8,Iris-virginica
# 1,7.7,3.8,6.7,2.2,Iris-virginica
# 1,7.7,2.6,6.9,2.3,Iris-virginica
# 1,6,2.2,5,1.5,Iris-virginica
# 1,6.9,3.2,5.7,2.3,Iris-virginica
# 1,5.6,2.8,4.9,2,Iris-virginica
# 1,7.7,2.8,6.7,2,Iris-virginica
# 1,6.3,2.7,4.9,1.8,Iris-virginica
# 1,6.7,3.3,5.7,2.1,Iris-virginica
# 1,7.2,3.2,6,1.8,Iris-virginica
# 1,6.2,2.8,4.8,1.8,Iris-virginica
# 1,6.1,3,4.9,1.8,Iris-virginica
# 1,6.4,2.8,5.6,2.1,Iris-virginica
# 1,7.2,3,5.8,1.6,Iris-virginica
# 1,7.4,2.8,6.1,1.9,Iris-virginica
# 1,7.9,3.8,6.4,2,Iris-virginica
# 1,6.4,2.8,5.6,2.2,Iris-virginica
# 1,6.3,2.8,5.1,1.5,Iris-virginica
# 1,6.1,2.6,5.6,1.4,Iris-virginica
# 1,7.7,3,6.1,2.3,Iris-virginica
# 1,6.3,3.4,5.6,2.4,Iris-virginica
# 1,6.4,3.1,5.5,1.8,Iris-virginica
# 1,6,3,4.8,1.8,Iris-virginica
# 1,6.9,3.1,5.4,2.1,Iris-virginica
# 1,6.7,3.1,5.6,2.4,Iris-virginica
# 1,6.9,3.1,5.1,2.3,Iris-virginica
# 1,5.8,2.7,5.1,1.9,Iris-virginica
# 1,6.8,3.2,5.9,2.3,Iris-virginica
# 1,6.7,3.3,5.7,2.5,Iris-virginica
# 1,6.7,3,5.2,2.3,Iris-virginica
# 1,6.3,2.5,5,1.9,Iris-virginica
# 1,6.5,3,5.2,2,Iris-virginica
# 1,6.2,3.4,5.4,2.3,Iris-virginica
# 1,5.9,3,5.1,1.8,Iris-virginica

# %%
import os
import xml.etree.ElementTree as ET
if os.path.exists("books.xml") and os.path.getsize("books.xml") > 0:
    tree = ET.parse("books.xml")
    root = tree.getroot()
    for child in root:
        print(child.tag, child.text)
else:
    print("File does not exist or is empty.")
# Out:
# book
#
# book
#
# book
#
# book
#
# book
#
# book
#
# book
#
# book
#
# book
#
# book
#
# book
#
# book
